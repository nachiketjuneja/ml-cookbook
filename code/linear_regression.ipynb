# %% [markdown]
# <a href="https://colab.research.google.com/github/nachiketjuneja/ml-cookbook/blob/main/code/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Linear Regression
## Dataset - house pricing dataset (Already available in the library)
# !pip install -U scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 63.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# %%
df = fetch_california_housing()
df
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
df = fetch_california_housing()
pd.DataFrame(df.data)
## Output has 12 cols which means I have 12 features here
# Out:
#             0     1         2         3       4         5      6       7
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.5568  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  1.8672  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  2.3886  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
# [20640 rows x 8 columns]

# %%
## Check all the features and replace them in the columns.
## print df to view all available attributes. All these are independent features

dataset = pd.DataFrame(df.data)
dataset.columns = df.feature_names
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127  ...  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137  ...  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136  ...  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352  ...  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853  ...  2.181467     37.85    -122.25
#
# [5 rows x 8 columns]

# %%
## Since this is housing pricing dataset, we can predict the price which would be the dependent feature
dataset['price']=df.target
dataset.head(50)
# Out:
#     MedInc  HouseAge  AveRooms  AveBedrms  ...  AveOccup  Latitude  Longitude  price
# 0   8.3252      41.0  6.984127   1.023810  ...  2.555556     37.88    -122.23  4.526
# 1   8.3014      21.0  6.238137   0.971880  ...  2.109842     37.86    -122.22  3.585
# 2   7.2574      52.0  8.288136   1.073446  ...  2.802260     37.85    -122.24  3.521
# 3   5.6431      52.0  5.817352   1.073059  ...  2.547945     37.85    -122.25  3.413
# 4   3.8462      52.0  6.281853   1.081081  ...  2.181467     37.85    -122.25  3.422
# 5   4.0368      52.0  4.761658   1.103627  ...  2.139896     37.85    -122.25  2.697
# 6   3.6591      52.0  4.931907   0.951362  ...  2.128405     37.84    -122.25  2.992
# 7   3.1200      52.0  4.797527   1.061824  ...  1.788253     37.84    -122.25  2.414
# 8   2.0804      42.0  4.294118   1.117647  ...  2.026891     37.84    -122.26  2.267
# 9   3.6912      52.0  4.970588   0.990196  ...  2.172269     37.84    -122.25  2.611
# ...

# %%
## Divide dataset to independent and dependent features
## use iloc to provide features which are dependent/independent

x=dataset.iloc[:,:-1] ## all cols except last one. independent features
y=dataset.iloc[:,-1] ## only last col. dependent feature
x.head()
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: price, dtype: float64
